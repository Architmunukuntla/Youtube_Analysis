# %%
df = spark.table("raw_youtube.default.clean_youtube_recommendation_dataset")
df.show(5)
df.printSchema()
# Out:
# +--------------------+------------------+-------------------+-----------+----------+----------+-------------+--------------+--------+----------+-------+---------------+--------------------+-----------------------+----------------+--------------+------------+----------------+---------------+
# |               title|     channel_title|       published_at|category_id|view_count|like_count|comment_count|favorite_count|duration|definition|caption|engagement_rate|likes_to_views_ratio|comments_to_views_ratio|duration_seconds|video_age_days|publish_year|popularity_level|video_age_group|
# +--------------------+------------------+-------------------+-----------+----------+----------+-------------+--------------+--------+----------+-------+---------------+--------------------+-----------------------+----------------+--------------+------------+----------------+---------------+
# |LA PERVERSA X LA ...|AlofokeMusicSounds|2025-11-16 15:34:55|         10|   1405647|    140463|         9063|             0| PT1M51S|        hd|  false|    0.106375138|       0.09992757789|         0.006447560129|             111|             1|        2025|            High|   Last 30 days|
# |Moana | Official ...|            Disney|2025-11-17 17:00:47|         24|   2776847|     26801|         6684|             0|    PT1M|        hd|   true|  0.01205863627|       0.00965159058|         0.002407045686|              60|             0|        2025|            High|   Last 30 days|
# |$0 - $1 Trillion ...|        CaylusBlox|2025-11-17 22:57:14|         20|   1189857|     16174|         1827|             0| PT18M2S|        hd|  false|  0.01512869603|       0.01359321869|         0.001535477343|            1082|             0|        2025|            High|   Last 30 days|
# |ALLDAY PROJECT - ...|     THEBLACKLABEL|2025-11-17 09:00:07|         10|   5319161|         0|        12869|             0| PT3M23S|        hd|   true| 0.002419366058|                 0.0|         0.002419366058|             203|             1|        2025|            High|   Last 30 days|
# |La Lupa | Vendett...|     PlayOverwatch|2025-11-17 17:00:06|         20|    597542|     41742|         4728|             0| PT3M35S|        hd|   true|  0.07776846185|       0.06985606057|         0.007912401283|             215|             0|        2025|            High|   Last 30 days|
# +--------------------+------------------+-------------------+-----------+----------+----------+-------------+--------------+--------+----------+-------+---------------+--------------------+-----------------------+----------------+--------------+------------+----------------+---------------+
# only showing top 5 rows
# root
#  |-- title: string (nullable = true)
#  |-- channel_title: string (nullable = true)
#  |-- published_at: timestamp (nullable = true)
#  |-- category_id: long (nullable = true)
#  |-- view_count: long (nullable = true)
#  |-- like_count: long (nullable = true)
#  |-- comment_count: long (nullable = true)
#  |-- favorite_count: long (nullable = true)
#  |-- duration: string (nullable = true)
#  |-- definition: string (nullable = true)
#  |-- caption: boolean (nullable = true)
#  |-- engagement_rate: double (nullable = true)
#  |-- likes_to_views_ratio: double (nullable = true)
#  |-- comments_to_views_ratio: double (nullable = true)
#  |-- duration_seconds: long (nullable = true)
#  |-- video_age_days: long (nullable = true)
#  |-- publish_year: integer (nullable = true)
#  |-- popularity_level: string (nullable = true)
#  |-- video_age_group: string (nullable = true)

# %%
## Basic stats
df.describe([
    "view_count",
    "like_count",
    "comment_count",
    "duration_seconds",
    "engagement_rate"
]).show()
# Out:
# +-------+--------------------+-----------------+------------------+-----------------+--------------------+
# |summary|          view_count|       like_count|     comment_count| duration_seconds|     engagement_rate|
# +-------+--------------------+-----------------+------------------+-----------------+--------------------+
# |  count|                 537|              537|               537|              537|                 537|
# |   mean|2.1457518182495344E7|433604.3891992551| 7125.700186219739|4802.746741154562| 0.02872167267042254|
# | stddev| 4.015199973521348E7|838671.0516481801|36075.115032054826|13748.24943697424|0.020608321913437946|
# |    min|                   0|                0|                 0|                0|                 0.0|
# |    max|           369731024|         10879340|            810641|           105227|        0.2157443164|
# +-------+--------------------+-----------------+------------------+-----------------+--------------------+

# %%
## Total views by category_id
from pyspark.sql.functions import sum

df_views_by_category = (
    df.groupBy("category_id")
      .agg(sum("view_count").alias("total_views"))
      .orderBy("total_views", ascending=False)
)

df_views_by_category.show()
# Out:
# +-----------+-----------+
# |category_id|total_views|
# +-----------+-----------+
# |         22| 3903414037|
# |         26| 2479319735|
# |         24| 1288240540|
# |         27|  937603557|
# |         10|  862209047|
# |         17|  822758038|
# |         20|  412279369|
# |          1|  311171272|
# |         28|  224771559|
# |         19|  146244379|
# |         23|  113199491|
# |         25|   21476240|
# +-----------+-----------+

# %%
## Average engagement_rate by category_id
from pyspark.sql.functions import avg

df_engagement_by_category = (
    df.groupBy("category_id")
      .agg(avg("engagement_rate").alias("avg_engagement_rate"))
      .orderBy("avg_engagement_rate", ascending=False)
)

df_engagement_by_category.show()
# Out:
# +-----------+--------------------+
# |category_id| avg_engagement_rate|
# +-----------+--------------------+
# |         10| 0.04063221717813726|
# |          1|0.034780604906900006|
# |         24|  0.0338282307842963|
# |         23| 0.03211848374666667|
# |         27|0.029512534495968006|
# |         28|0.028985881452030564|
# |         20| 0.02877360812367896|
# |         22|0.025623078815054545|
# |         19|0.019858830286687498|
# |         25|       0.01808144313|
# |         26|0.017967861539340428|
# |         17|0.017414363630666667|
# +-----------+--------------------+

# %%
## Popularity distribution (Low / Medium / High)
df_popularity = (
    df.groupBy("popularity_level")
      .count()
      .orderBy("popularity_level")
)

df_popularity.show()
# Out:
# +----------------+-----+
# |popularity_level|count|
# +----------------+-----+
# |            High|  523|
# |             Low|    1|
# |          Medium|   13|
# +----------------+-----+

# %%
## Required query: total views per category
# %sql
SELECT
  category_id,
  SUM(view_count) AS total_views
FROM raw_youtube.default.clean_youtube_recommendation_dataset
GROUP BY category_id
ORDER BY total_views DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category_id</th><th>total_views</th></tr></thead><tbody><tr><td>22</td><td>3903414037</td></tr><tr><td>26</td><td>2479319735</td></tr><tr><td>24</td><td>1288240540</td></tr><tr><td>27</td><td>937603557</td></tr><tr><td>10</td><td>862209047</td></tr><tr><td>17</td><td>822758038</td></tr><tr><td>20</td><td>412279369</td></tr><tr><td>1</td><td>311171272</td></tr><tr><td>28</td><td>224771559</td></tr><tr><td>19</td><td>146244379</td></tr><tr><td>23</td><td>113199491</td></tr><tr><td>25</td><td>21476240</td></tr></tbody></table></div>

# %%
df = spark.sql(
  """
  SELECT
    publish_year,
    AVG(engagement_rate) AS avg_engagement_rate
  FROM raw_youtube.default.clean_youtube_recommendation_dataset
  GROUP BY publish_year
  ORDER BY publish_year
  """
)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>publish_year</th><th>avg_engagement_rate</th></tr></thead><tbody><tr><td>2012</td><td>0.007820732745</td></tr><tr><td>2013</td><td>0.006788561240000001</td></tr><tr><td>2014</td><td>0.013233719031000001</td></tr><tr><td>2015</td><td>0.008937465880999999</td></tr><tr><td>2016</td><td>0.012804339436</td></tr><tr><td>2017</td><td>0.017298094478615383</td></tr><tr><td>2018</td><td>0.01785280410564706</td></tr><tr><td>2019</td><td>0.020999664314636367</td></tr><tr><td>2020</td><td>0.019842399304531248</td></tr><tr><td>2021</td><td>0.026720499878942854</td></tr><tr><td>2022</td><td>0.026424254386928574</td></tr><tr><td>2023</td><td>0.03537108563348954</td></tr><tr><td>2024</td><td>0.028591725116437827</td></tr><tr><td>2025</td><td>0.03244933448242937</td></tr></tbody></table></div>
