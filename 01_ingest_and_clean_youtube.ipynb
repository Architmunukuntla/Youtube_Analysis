# %%
from pyspark.sql.functions import col, when, to_timestamp, year

df_raw = spark.table("raw_youtube.default.raw_youtube_recommendation_dataset")
df_raw.show(5)
df_raw.printSchema()
# Out:
# +--------------------+------------------+-------------------+-----------+----------+----------+-------------+--------------+--------+----------+-------+---------------+--------------------+-----------------------+----------------+--------------+
# |               Title|     channel_title|       published_at|category_id|view_count|like_count|comment_count|favorite_count|duration|definition|caption|engagement_rate|likes_to_views_ratio|comments_to_views_ratio|duration_seconds|video_age_days|
# +--------------------+------------------+-------------------+-----------+----------+----------+-------------+--------------+--------+----------+-------+---------------+--------------------+-----------------------+----------------+--------------+
# |LA PERVERSA X LA ...|AlofokeMusicSounds|2025-11-16 15:34:55|         10|   1405647|    140463|         9063|             0| PT1M51S|        hd|  false|    0.106375138|       0.09992757789|         0.006447560129|             111|             1|
# |Moana | Official ...|            Disney|2025-11-17 17:00:47|         24|   2776847|     26801|         6684|             0|    PT1M|        hd|   true|  0.01205863627|       0.00965159058|         0.002407045686|              60|             0|
# |$0 - $1 Trillion ...|        CaylusBlox|2025-11-17 22:57:14|         20|   1189857|     16174|         1827|             0| PT18M2S|        hd|  false|  0.01512869603|       0.01359321869|         0.001535477343|            1082|             0|
# |ALLDAY PROJECT - ...|     THEBLACKLABEL|2025-11-17 09:00:07|         10|   5319161|         0|        12869|             0| PT3M23S|        hd|   true| 0.002419366058|                 0.0|         0.002419366058|             203|             1|
# |La Lupa | Vendett...|     PlayOverwatch|2025-11-17 17:00:06|         20|    597542|     41742|         4728|             0| PT3M35S|        hd|   true|  0.07776846185|       0.06985606057|         0.007912401283|             215|             0|
# +--------------------+------------------+-------------------+-----------+----------+----------+-------------+--------------+--------+----------+-------+---------------+--------------------+-----------------------+----------------+--------------+
# only showing top 5 rows
# root
#  |-- Title: string (nullable = true)
#  |-- channel_title: string (nullable = true)
#  |-- published_at: timestamp (nullable = true)
#  |-- category_id: long (nullable = true)
#  |-- view_count: long (nullable = true)
#  |-- like_count: long (nullable = true)
#  |-- comment_count: long (nullable = true)
#  |-- favorite_count: long (nullable = true)
#  |-- duration: string (nullable = true)
#  |-- definition: string (nullable = true)
#  |-- caption: boolean (nullable = true)
#  |-- engagement_rate: double (nullable = true)
#  |-- likes_to_views_ratio: double (nullable = true)
#  |-- comments_to_views_ratio: double (nullable = true)
#  |-- duration_seconds: long (nullable = true)
#  |-- video_age_days: long (nullable = true)

# %%
from pyspark.sql.functions import col, when, to_timestamp, year

df_clean = (
    df_raw
    # optional: make title lowercase name for easier use
    .withColumnRenamed("Title", "title")
    # cast numeric columns
    .withColumn("view_count", col("view_count").cast("long"))
    .withColumn("like_count", col("like_count").cast("long"))
    .withColumn("comment_count", col("comment_count").cast("long"))
    .withColumn("favorite_count", col("favorite_count").cast("long"))
    .withColumn("engagement_rate", col("engagement_rate").cast("double"))
    .withColumn("likes_to_views_ratio", col("likes_to_views_ratio").cast("double"))
    .withColumn("comments_to_views_ratio", col("comments_to_views_ratio").cast("double"))
    .withColumn("duration_seconds", col("duration_seconds").cast("long"))
    .withColumn("video_age_days", col("video_age_days").cast("long"))
    # convert publish time to timestamp
    .withColumn("published_at", to_timestamp(col("published_at")))
)

# Add publish_year from published_at
df_clean = df_clean.withColumn(
    "publish_year",
    year(col("published_at"))
)

# Add popularity_level based on view_count
df_clean = df_clean.withColumn(
    "popularity_level",
    when(col("view_count") < 10_000, "Low")
    .when(col("view_count") < 100_000, "Medium")
    .otherwise("High")
)

# Add video_age_group based on video_age_days
df_clean = df_clean.withColumn(
    "video_age_group",
    when(col("video_age_days") < 30, "Last 30 days")
    .when(col("video_age_days") < 365, "Last year")
    .otherwise("Older")
)

df_clean.show(5)
df_clean.printSchema()
# Out:
# +--------------------+------------------+-------------------+-----------+----------+----------+-------------+--------------+--------+----------+-------+---------------+--------------------+-----------------------+----------------+--------------+------------+----------------+---------------+
# |               title|     channel_title|       published_at|category_id|view_count|like_count|comment_count|favorite_count|duration|definition|caption|engagement_rate|likes_to_views_ratio|comments_to_views_ratio|duration_seconds|video_age_days|publish_year|popularity_level|video_age_group|
# +--------------------+------------------+-------------------+-----------+----------+----------+-------------+--------------+--------+----------+-------+---------------+--------------------+-----------------------+----------------+--------------+------------+----------------+---------------+
# |LA PERVERSA X LA ...|AlofokeMusicSounds|2025-11-16 15:34:55|         10|   1405647|    140463|         9063|             0| PT1M51S|        hd|  false|    0.106375138|       0.09992757789|         0.006447560129|             111|             1|        2025|            High|   Last 30 days|
# |Moana | Official ...|            Disney|2025-11-17 17:00:47|         24|   2776847|     26801|         6684|             0|    PT1M|        hd|   true|  0.01205863627|       0.00965159058|         0.002407045686|              60|             0|        2025|            High|   Last 30 days|
# |$0 - $1 Trillion ...|        CaylusBlox|2025-11-17 22:57:14|         20|   1189857|     16174|         1827|             0| PT18M2S|        hd|  false|  0.01512869603|       0.01359321869|         0.001535477343|            1082|             0|        2025|            High|   Last 30 days|
# |ALLDAY PROJECT - ...|     THEBLACKLABEL|2025-11-17 09:00:07|         10|   5319161|         0|        12869|             0| PT3M23S|        hd|   true| 0.002419366058|                 0.0|         0.002419366058|             203|             1|        2025|            High|   Last 30 days|
# |La Lupa | Vendett...|     PlayOverwatch|2025-11-17 17:00:06|         20|    597542|     41742|         4728|             0| PT3M35S|        hd|   true|  0.07776846185|       0.06985606057|         0.007912401283|             215|             0|        2025|            High|   Last 30 days|
# +--------------------+------------------+-------------------+-----------+----------+----------+-------------+--------------+--------+----------+-------+---------------+--------------------+-----------------------+----------------+--------------+------------+----------------+---------------+
# only showing top 5 rows
# root
#  |-- title: string (nullable = true)
#  |-- channel_title: string (nullable = true)
#  |-- published_at: timestamp (nullable = true)
#  |-- category_id: long (nullable = true)
#  |-- view_count: long (nullable = true)
#  |-- like_count: long (nullable = true)
#  |-- comment_count: long (nullable = true)
#  |-- favorite_count: long (nullable = true)
#  |-- duration: string (nullable = true)
#  |-- definition: string (nullable = true)
#  |-- caption: boolean (nullable = true)
#  |-- engagement_rate: double (nullable = true)
#  |-- likes_to_views_ratio: double (nullable = true)
#  |-- comments_to_views_ratio: double (nullable = true)
#  |-- duration_seconds: long (nullable = true)
#  |-- video_age_days: long (nullable = true)
#  |-- publish_year: integer (nullable = true)
#  |-- popularity_level: string (nullable = false)
#  |-- video_age_group: string (nullable = false)

# %%
df_clean.write.mode("overwrite").saveAsTable("raw_youtube.default.clean_youtube_recommendation_dataset")
